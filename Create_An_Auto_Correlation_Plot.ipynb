# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashjairam/time-series-forecasting-with-python/blob/main/Create_An_Auto_Correlation_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create multiple scatter plots
from pandas import read_csv
from matplotlib import pyplot as plt
from pandas.plotting import autocorrelation_plot

# %%
#reading in csv file
series = read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True).squeeze('columns')

# %%
#generating an autocorrelation plot
autocorrelation_plot(series)
plt.show()
